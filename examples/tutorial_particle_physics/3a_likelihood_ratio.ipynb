# %% [markdown]
# # MadMiner particle physics tutorial
#
# # Part 3a: Training a likelihood ratio estimator
#
# Johann Brehmer, Felix Kling, Irina Espejo, and Kyle Cranmer 2018-2019

# %% [markdown]
# In part 3a of this tutorial we will finally train a neural network to estimate likelihood ratios. We assume that you have run part 1 and 2a of this tutorial. If, instead of 2a, you have run part 2b, you just have to load a different filename later.

# %% [markdown]
# ## Preparations

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

import logging
import numpy as np
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

from madminer.sampling import SampleAugmenter
from madminer import sampling
from madminer.ml import ParameterizedRatioEstimator

# %%
# MadMiner output
logging.basicConfig(
    format='%(asctime)-5.5s %(name)-20.20s %(levelname)-7.7s %(message)s',
    datefmt='%H:%M',
    level=logging.INFO
)

# Output of all other modules (e.g. matplotlib)
for key in logging.Logger.manager.loggerDict:
    if "madminer" not in key:
        logging.getLogger(key).setLevel(logging.WARNING)

# %% [markdown]
# ## 1. Make (unweighted) training and test samples with augmented data

# %% [markdown]
# At this point, we have all the information we need from the simulations. But the data is not quite ready to be used for machine learning. The `madminer.sampling` class `SampleAugmenter` will take care of the remaining book-keeping steps before we can train our estimators:
#
# First, it unweights the samples, i.e. for a given parameter vector `theta` (or a distribution `p(theta)`) it picks events `x` such that their distribution follows `p(x|theta)`. The selected samples will all come from the event file we have so far, but their frequency is changed -- some events will appear multiple times, some will disappear.
#
# Second, `SampleAugmenter` calculates all the augmented data ("gold") that is the key to our new inference methods. Depending on the specific technique, these are the joint likelihood ratio and / or the joint score. It saves all these pieces of information for the selected events in a set of numpy files that can easily be used in any machine learning framework.

# %%
sampler = SampleAugmenter('data/lhe_data_shuffled.h5')
# sampler = SampleAugmenter('data/delphes_data_shuffled.h5')
# Out:
# 01:02 madminer.analysis    INFO    Loading data from data/lhe_data_shuffled.h5
# 01:02 madminer.analysis    INFO    Found 2 parameters
# 01:02 madminer.analysis    INFO    Did not find nuisance parameters
# 01:02 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 01:02 madminer.analysis    INFO    Found 3 observables
# 01:02 madminer.analysis    INFO    Found 89987 events
# 01:02 madminer.analysis    INFO      49988 signal events sampled from benchmark sm
# 01:02 madminer.analysis    INFO      10000 signal events sampled from benchmark w
# 01:02 madminer.analysis    INFO      10000 signal events sampled from benchmark neg_w
# 01:02 madminer.analysis    INFO      10000 signal events sampled from benchmark ww
# 01:02 madminer.analysis    INFO      9999 signal events sampled from benchmark neg_ww
# 01:02 madminer.analysis    INFO    Found morphing setup with 6 components
# 01:02 madminer.analysis    INFO    Did not find nuisance morphing setup

# %% [markdown]
# The `SampleAugmenter` class defines five different high-level functions to generate train or test samples:
# - `sample_train_plain()`, which only saves observations x, for instance for histograms or ABC;
# - `sample_train_local()` for methods like SALLY and SALLINO, which will be demonstrated in the second part of the tutorial;
# - `sample_train_density()` for neural density estimation techniques like MAF or SCANDAL;
# - `sample_train_ratio()` for techniques like CARL, ROLR, CASCAL, and RASCAL, when only theta0 is parameterized;
# - `sample_train_more_ratios()` for the same techniques, but with both theta0 and theta1 parameterized;
# - `sample_test()` for the evaluation of any method.
#
# For the arguments `theta`, `theta0`, or `theta1`, you can (and should!) use the helper functions `benchmark()`, `benchmarks()`, `morphing_point()`, `morphing_points()`, and `random_morphing_points()`, all defined in the `madminer.sampling` module.
#
# Here we'll train a likelihood ratio estimator with the ALICES method, so we focus on the `extract_samples_train_ratio()` function. We'll sample the numerator hypothesis in the likelihood ratio with 1000 points drawn from a Gaussian prior, and fix the denominator hypothesis to the SM.
#
# Note the keyword `sample_only_from_closest_benchmark=True`, which makes sure that for each parameter point we only use the events that were originally (in MG) generated from the closest benchmark. This reduces the statistical fluctuations in the outcome quite a bit.

# %%
x, theta0, theta1, y, r_xz, t_xz, n_effective = sampler.sample_train_ratio(
    theta0=sampling.random_morphing_points(1000, [('gaussian', 0., 15.), ('gaussian', 0., 15.)]),
    theta1=sampling.benchmark('sm'),
    n_samples=100000,
    folder='./data/samples',
    filename='train_ratio',
    sample_only_from_closest_benchmark=True,
    return_individual_n_effective=True,
)
# Out:
# 01:02 madminer.sampling    INFO    Extracting training sample for ratio-based methods. Numerator hypothesis: 1000 random morphing points, drawn from the following priors:
#   theta_0 ~ Gaussian with mean 0.0 and std 15.0
#   theta_1 ~ Gaussian with mean 0.0 and std 15.0, denominator hypothesis: sm
# 01:02 madminer.sampling    INFO    Starting sampling serially
# 01:02 madminer.sampling    WARNING Large statistical uncertainty on the total cross section when sampling from theta = [-1.6368396  3.0512195]: (0.004109 +/- 0.001236) pb (30.078070106827912 %). Skipping these warnings in the future...
# 01:02 madminer.sampling    INFO    Sampling from parameter point 50 / 1000
# 01:02 madminer.sampling    INFO    Sampling from parameter point 100 / 1000
# 01:02 madminer.sampling    INFO    Sampling from parameter point 150 / 1000
# 01:02 madminer.sampling    INFO    Sampling from parameter point 200 / 1000
# 01:02 madminer.sampling    INFO    Sampling from parameter point 250 / 1000
# 01:02 madminer.sampling    INFO    Sampling from parameter point 300 / 1000
# 01:02 madminer.sampling    INFO    Sampling from parameter point 350 / 1000
# 01:02 madminer.sampling    INFO    Sampling from parameter point 400 / 1000
# 01:02 madminer.sampling    INFO    Sampling from parameter point 450 / 1000
# 01:02 madminer.sampling    INFO    Sampling from parameter point 500 / 1000
# 01:02 madminer.sampling    INFO    Sampling from parameter point 550 / 1000
# 01:02 madminer.sampling    INFO    Sampling from parameter point 600 / 1000
# 01:02 madminer.sampling    INFO    Sampling from parameter point 650 / 1000
# 01:02 madminer.sampling    INFO    Sampling from parameter point 700 / 1000
# 01:02 madminer.sampling    INFO    Sampling from parameter point 750 / 1000
# 01:02 madminer.sampling    INFO    Sampling from parameter point 800 / 1000
# 01:02 madminer.sampling    INFO    Sampling from parameter point 850 / 1000
# 01:02 madminer.sampling    INFO    Sampling from parameter point 900 / 1000
# 01:02 madminer.sampling    INFO    Sampling from parameter point 950 / 1000
# 01:02 madminer.sampling    INFO    Sampling from parameter point 1000 / 1000
# 01:02 madminer.sampling    INFO    Effective number of samples: mean 611.7719465698084, with individual thetas ranging from 6.282837265900869 to 5530.476175086298
# 01:02 madminer.sampling    INFO    Starting sampling serially
# 01:03 madminer.sampling    INFO    Sampling from parameter point 50 / 1000
# 01:03 madminer.sampling    INFO    Sampling from parameter point 100 / 1000
# 01:03 madminer.sampling    INFO    Sampling from parameter point 150 / 1000
# 01:03 madminer.sampling    INFO    Sampling from parameter point 200 / 1000
# 01:03 madminer.sampling    INFO    Sampling from parameter point 250 / 1000
# 01:03 madminer.sampling    INFO    Sampling from parameter point 300 / 1000
# 01:03 madminer.sampling    INFO    Sampling from parameter point 350 / 1000
# 01:03 madminer.sampling    INFO    Sampling from parameter point 400 / 1000
# 01:03 madminer.sampling    INFO    Sampling from parameter point 450 / 1000
# 01:03 madminer.sampling    INFO    Sampling from parameter point 500 / 1000
# 01:03 madminer.sampling    INFO    Sampling from parameter point 550 / 1000
# 01:03 madminer.sampling    INFO    Sampling from parameter point 600 / 1000
# 01:03 madminer.sampling    INFO    Sampling from parameter point 650 / 1000
# 01:03 madminer.sampling    INFO    Sampling from parameter point 700 / 1000
# 01:03 madminer.sampling    INFO    Sampling from parameter point 750 / 1000
# 01:03 madminer.sampling    INFO    Sampling from parameter point 800 / 1000
# 01:03 madminer.sampling    INFO    Sampling from parameter point 850 / 1000
# 01:03 madminer.sampling    INFO    Sampling from parameter point 900 / 1000
# 01:03 madminer.sampling    INFO    Sampling from parameter point 950 / 1000
# 01:03 madminer.sampling    INFO    Sampling from parameter point 1000 / 1000
# 01:03 madminer.sampling    INFO    Effective number of samples: mean 29982.999999999996, with individual thetas ranging from 29982.999999999996 to 29982.999999999996

# %% [markdown]
# For the evaluation we'll need a test sample:

# %%
_ = sampler.sample_test(
    theta=sampling.benchmark('sm'),
    n_samples=1000,
    folder='./data/samples',
    filename='test'
)
# Out:
# 01:04 madminer.sampling    INFO    Extracting evaluation sample. Sampling according to sm
# 01:04 madminer.sampling    INFO    Starting sampling serially
# 01:04 madminer.sampling    INFO    Sampling from parameter point 1 / 1
# 01:04 madminer.sampling    INFO    Effective number of samples: mean 9986.000000000002, with individual thetas ranging from 9986.000000000002 to 9986.000000000002

# %% [markdown]
# You might notice the information about the "eeffective number of samples" in the output. This is defined as `1 / max_events(weights)`; the smaller it is, the bigger the statistical fluctuations from too large weights. Let's plot this over the parameter space:

# %%
cmin, cmax = 10., 1000.

cut = (y.flatten()==0)

fig = plt.figure(figsize=(5,4))

sc = plt.scatter(theta0[cut][:,0], theta0[cut][:,1], c=n_effective[cut],
                 s=60., cmap='viridis',
                 norm=matplotlib.colors.LogNorm(vmin=cmin, vmax=cmax),
                 marker='o')

cb = plt.colorbar(sc)
cb.set_label('Effective number of samples')

plt.xlim(-25.,25.)
plt.ylim(-25.,25.)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 2. Plot cross section over parameter space

# %% [markdown]
# This is not strictly necessary, but we can also plot the cross section as a function of parameter space:

# %%
thetas_benchmarks, xsecs_benchmarks, xsec_errors_benchmarks = sampler.cross_sections(
    theta=sampling.benchmarks(list(sampler.benchmarks.keys()))
)

thetas_morphing, xsecs_morphing, xsec_errors_morphing = sampler.cross_sections(
    theta=sampling.random_morphing_points(1000, [('gaussian', 0., 4.), ('gaussian', 0., 4.)])
)
# Out:
# 01:06 madminer.sampling    INFO    Starting cross-section calculation
# 01:06 madminer.sampling    INFO    Starting cross-section calculation

# %%
cmin, cmax = 0., 2.5 * np.mean(xsecs_morphing)

fig = plt.figure(figsize=(5,4))

sc = plt.scatter(thetas_morphing[:,0], thetas_morphing[:,1], c=xsecs_morphing,
            s=40., cmap='viridis', vmin=cmin, vmax=cmax,
            marker='o')

plt.scatter(thetas_benchmarks[:,0], thetas_benchmarks[:,1], c=xsecs_benchmarks,
            s=200., cmap='viridis', vmin=cmin, vmax=cmax, lw=2., edgecolor='black',
            marker='s')

cb = plt.colorbar(sc)
cb.set_label('xsec [pb]')

plt.xlim(-10.,10.)
plt.ylim(-10.,10.)
plt.tight_layout()
plt.show()

# %% [markdown]
# What  you see here is a morphing algorithm in action. We only asked MadGraph to calculate event weights (differential cross sections, or basically squared matrix elements) at six fixed parameter points (shown here as squares with black edges). But with our knowledge about the structure of the process we can interpolate any observable to any parameter point without loss (except that statistical uncertainties might increase)!

# %% [markdown]
# ## 3. Train likelihood ratio estimator

# %% [markdown]
# It's now time to build the neural network that estimates the likelihood ratio. The central object for this is the `madminer.ml.ParameterizedRatioEstimator` class. It defines functions that train, save, load, and evaluate the estimators.
#
# In the initialization, the keywords `n_hidden` and `activation` define the architecture of the (fully connected) neural network:

# %%
estimator = ParameterizedRatioEstimator(
    n_hidden=(100,),
    activation="tanh"
)

# %% [markdown]
# To train this model we will minimize the ALICES loss function described in ["Likelihood-free inference with an improved cross-entropy estimator"](https://arxiv.org/abs/1808.00973). Many alternatives, including RASCAL, are described in ["Constraining Effective Field Theories With Machine Learning"](https://arxiv.org/abs/1805.00013) and ["A Guide to Constraining Effective Field Theories With Machine Learning"](https://arxiv.org/abs/1805.00020). There is also SCANDAL introduced in ["Mining gold from implicit models to improve likelihood-free inference"](https://arxiv.org/abs/1805.12244).

# %%
estimator.train(
    method='alices',
    theta='data/samples/theta0_train_ratio.npy',
    x='data/samples/x_train_ratio.npy',
    y='data/samples/y_train_ratio.npy',
    r_xz='data/samples/r_xz_train_ratio.npy',
    t_xz='data/samples/t_xz_train_ratio.npy',
    alpha=1.,
    n_epochs=20,
)

estimator.save('models/alices')
# Out:
# 01:38 madminer.ml          INFO    Starting training
# 01:38 madminer.ml          INFO      Method:                 alices
# 01:38 madminer.ml          INFO      alpha:                  1.0
# 01:38 madminer.ml          INFO      Batch size:             128
# 01:38 madminer.ml          INFO      Optimizer:              amsgrad
# 01:38 madminer.ml          INFO      Epochs:                 20
# 01:38 madminer.ml          INFO      Learning rate:          0.001 initially, decaying to 0.0001
# 01:38 madminer.ml          INFO      Validation split:       0.25
# 01:38 madminer.ml          INFO      Early stopping:         True
# 01:38 madminer.ml          INFO      Scale inputs:           True
# 01:38 madminer.ml          INFO      Scale parameters:       True
# 01:38 madminer.ml          INFO      Shuffle labels          False
# 01:38 madminer.ml          INFO      Samples:                all
# 01:38 madminer.ml          INFO    Loading training data
# 01:38 madminer.utils.vario INFO      Loading data/samples/theta0_train_ratio.npy into RAM
# 01:38 madminer.utils.vario INFO      Loading data/samples/x_train_ratio.npy into RAM
# 01:38 madminer.utils.vario INFO      Loading data/samples/y_train_ratio.npy into RAM
# 01:38 madminer.utils.vario INFO      Loading data/samples/r_xz_train_ratio.npy into RAM
# 01:38 madminer.utils.vario INFO      Loading data/samples/t_xz_train_ratio.npy into RAM
# 01:38 madminer.ml          INFO    Found 100000 samples with 2 parameters and 3 observables
# 01:38 madminer.ml          INFO    Setting up input rescaling
# 01:38 madminer.ml          INFO    Rescaling parameters
# 01:38 madminer.ml          INFO    Setting up parameter rescaling
# 01:38 madminer.ml          INFO    Creating model
# 01:38 madminer.ml          INFO    Training model
# 01:38 madminer.utils.ml.tr INFO    Training on CPU with single precision
# 01:38 madminer.utils.ml.tr INFO    Epoch   1: train loss  2.15418 (improved_xe:  0.453, mse_score:  1.701)
# 01:38 madminer.utils.ml.tr INFO               val. loss   1.97083 (improved_xe:  0.417, mse_score:  1.554)
# 01:38 madminer.utils.ml.tr INFO    Epoch   2: train loss  2.05684 (improved_xe:  0.414, mse_score:  1.643)
# 01:38 madminer.utils.ml.tr INFO               val. loss   1.92088 (improved_xe:  0.409, mse_score:  1.511)
# 01:38 madminer.utils.ml.tr INFO    Epoch   3: train loss  2.02039 (improved_xe:  0.409, mse_score:  1.612)
# 01:38 madminer.utils.ml.tr INFO               val. loss   1.89366 (improved_xe:  0.406, mse_score:  1.488)
# 01:39 madminer.utils.ml.tr INFO    Epoch   4: train loss  1.99524 (improved_xe:  0.406, mse_score:  1.589)
# 01:39 madminer.utils.ml.tr INFO               val. loss   1.86599 (improved_xe:  0.404, mse_score:  1.462)
# 01:39 madminer.utils.ml.tr INFO    Epoch   5: train loss  1.97709 (improved_xe:  0.404, mse_score:  1.573)
# 01:39 madminer.utils.ml.tr INFO               val. loss   1.85666 (improved_xe:  0.402, mse_score:  1.454)
# 01:39 madminer.utils.ml.tr INFO    Epoch   6: train loss  1.96452 (improved_xe:  0.403, mse_score:  1.562)
# 01:39 madminer.utils.ml.tr INFO               val. loss   1.83578 (improved_xe:  0.401, mse_score:  1.435)
# 01:39 madminer.utils.ml.tr INFO    Epoch   7: train loss  1.95033 (improved_xe:  0.402, mse_score:  1.548)
# 01:39 madminer.utils.ml.tr INFO               val. loss   1.82760 (improved_xe:  0.400, mse_score:  1.427)
# 01:39 madminer.utils.ml.tr INFO    Epoch   8: train loss  1.94066 (improved_xe:  0.401, mse_score:  1.540)
# 01:39 madminer.utils.ml.tr INFO               val. loss   1.81774 (improved_xe:  0.399, mse_score:  1.418)
# 01:39 madminer.utils.ml.tr INFO    Epoch   9: train loss  1.93209 (improved_xe:  0.400, mse_score:  1.532)
# 01:39 madminer.utils.ml.tr INFO               val. loss   1.81053 (improved_xe:  0.400, mse_score:  1.411)
# 01:39 madminer.utils.ml.tr INFO    Epoch  10: train loss  1.92494 (improved_xe:  0.400, mse_score:  1.525)
# 01:39 madminer.utils.ml.tr INFO               val. loss   1.82005 (improved_xe:  0.398, mse_score:  1.422)
# 01:39 madminer.utils.ml.tr INFO    Epoch  11: train loss  1.91839 (improved_xe:  0.399, mse_score:  1.519)
# 01:39 madminer.utils.ml.tr INFO               val. loss   1.80571 (improved_xe:  0.397, mse_score:  1.408)
# 01:39 madminer.utils.ml.tr INFO    Epoch  12: train loss  1.91276 (improved_xe:  0.399, mse_score:  1.514)
# 01:39 madminer.utils.ml.tr INFO               val. loss   1.79257 (improved_xe:  0.397, mse_score:  1.395)
# 01:39 madminer.utils.ml.tr INFO    Epoch  13: train loss  1.90800 (improved_xe:  0.398, mse_score:  1.510)
# 01:39 madminer.utils.ml.tr INFO               val. loss   1.78591 (improved_xe:  0.397, mse_score:  1.389)
# 01:39 madminer.utils.ml.tr INFO    Epoch  14: train loss  1.90358 (improved_xe:  0.398, mse_score:  1.506)
# 01:39 madminer.utils.ml.tr INFO               val. loss   1.78387 (improved_xe:  0.397, mse_score:  1.387)
# 01:39 madminer.utils.ml.tr INFO    Epoch  15: train loss  1.90016 (improved_xe:  0.398, mse_score:  1.502)
# 01:39 madminer.utils.ml.tr INFO               val. loss   1.78177 (improved_xe:  0.396, mse_score:  1.386)
# 01:39 madminer.utils.ml.tr INFO    Epoch  16: train loss  1.89623 (improved_xe:  0.397, mse_score:  1.499)
# 01:39 madminer.utils.ml.tr INFO               val. loss   1.77880 (improved_xe:  0.396, mse_score:  1.383)
# 01:39 madminer.utils.ml.tr INFO    Epoch  17: train loss  1.89398 (improved_xe:  0.397, mse_score:  1.497)
# 01:39 madminer.utils.ml.tr INFO               val. loss   1.77322 (improved_xe:  0.396, mse_score:  1.378)
# 01:40 madminer.utils.ml.tr INFO    Epoch  18: train loss  1.89091 (improved_xe:  0.397, mse_score:  1.494)
# 01:40 madminer.utils.ml.tr INFO               val. loss   1.77056 (improved_xe:  0.395, mse_score:  1.375)
# 01:40 madminer.utils.ml.tr INFO    Epoch  19: train loss  1.88842 (improved_xe:  0.397, mse_score:  1.492)
# 01:40 madminer.utils.ml.tr INFO               val. loss   1.76855 (improved_xe:  0.395, mse_score:  1.374)
# 01:40 madminer.utils.ml.tr INFO    Epoch  20: train loss  1.88658 (improved_xe:  0.397, mse_score:  1.490)
# 01:40 madminer.utils.ml.tr INFO               val. loss   1.76794 (improved_xe:  0.395, mse_score:  1.373)
# 01:40 madminer.utils.ml.tr INFO    Early stopping did not improve performance
# 01:40 madminer.utils.ml.tr INFO    Training time spend on:
# 01:40 madminer.utils.ml.tr INFO                      initialize model:   0.00h
# 01:40 madminer.utils.ml.tr INFO                                   ALL:   0.03h
# 01:40 madminer.utils.ml.tr INFO                            check data:   0.00h
# 01:40 madminer.utils.ml.tr INFO                          make dataset:   0.00h
# 01:40 madminer.utils.ml.tr INFO                       make dataloader:   0.00h
# 01:40 madminer.utils.ml.tr INFO                       setup optimizer:   0.00h
# 01:40 madminer.utils.ml.tr INFO                   initialize training:   0.00h
# 01:40 madminer.utils.ml.tr INFO                                set lr:   0.00h
# 01:40 madminer.utils.ml.tr INFO                   load training batch:   0.01h
# 01:40 madminer.utils.ml.tr INFO                        fwd: move data:   0.00h
# 01:40 madminer.utils.ml.tr INFO                   fwd: check for nans:   0.00h
# 01:40 madminer.utils.ml.tr INFO                    fwd: model.forward:   0.01h
# 01:40 madminer.utils.ml.tr INFO                 fwd: calculate losses:   0.00h
# 01:40 madminer.utils.ml.tr INFO                 training forward pass:   0.01h
# 01:40 madminer.utils.ml.tr INFO                   training sum losses:   0.00h
# 01:40 madminer.utils.ml.tr INFO                        opt: zero grad:   0.00h
# 01:40 madminer.utils.ml.tr INFO                         opt: backward:   0.00h
# 01:40 madminer.utils.ml.tr INFO                   opt: clip grad norm:   0.00h
# 01:40 madminer.utils.ml.tr INFO                             opt: step:   0.00h
# 01:40 madminer.utils.ml.tr INFO                        optimizer step:   0.00h
# 01:40 madminer.utils.ml.tr INFO                 load validation batch:   0.00h
# 01:40 madminer.utils.ml.tr INFO               validation forward pass:   0.00h
# 01:40 madminer.utils.ml.tr INFO                 validation sum losses:   0.00h
# 01:40 madminer.utils.ml.tr INFO                        early stopping:   0.00h
# 01:40 madminer.utils.ml.tr INFO                          report epoch:   0.00h
# 01:40 madminer.ml          INFO    Saving model to models/alices

# %% [markdown]
# ## 4. Evaluate likelihood ratio estimator

# %% [markdown]
# `estimator.evaluate_log_likelihood_ratio(theta,x)` estimated the log likelihood ratio and the score for all combination between the given phase-space points `x` and parameters `theta`. That is, if given 100 events `x` and a grid of 25 `theta` points, it will return 25\*100 estimates for the log likelihood ratio and 25\*100 estimates for the score, both indexed by `[i_theta,i_x]`.

# %%
theta_each = np.linspace(-20.,20.,21)
theta0, theta1 = np.meshgrid(theta_each, theta_each)
theta_grid = np.vstack((theta0.flatten(), theta1.flatten())).T
np.save('data/samples/theta_grid.npy', theta_grid)

theta_denom = np.array([[0.,0.]])
np.save('data/samples/theta_ref.npy', theta_denom)

# %%
estimator.load('models/alices')

log_r_hat, _ = estimator.evaluate_log_likelihood_ratio(
    theta='data/samples/theta_grid.npy',
    x='data/samples/x_test.npy',
    evaluate_score=False
)
# Out:
# 01:40 madminer.ml          INFO    Loading model from models/alices
# 01:40 madminer.ml          INFO    Loading evaluation data
# 01:40 madminer.utils.vario INFO      Loading data/samples/x_test.npy into RAM
# 01:40 madminer.utils.vario INFO      Loading data/samples/theta_grid.npy into RAM
# 01:40 madminer.ml          INFO    Starting ratio evaluation for 441000 x-theta combinations
# 01:40 madminer.ml          INFO    Evaluation done

# %% [markdown]
# Let's look at the result:

# %%
bin_size = theta_each[1] - theta_each[0]
edges = np.linspace(theta_each[0] - bin_size/2, theta_each[-1] + bin_size/2, len(theta_each)+1)

fig = plt.figure(figsize=(6,5))
ax = plt.gca()

expected_llr = np.mean(log_r_hat,axis=1)
best_fit = theta_grid[np.argmin(-2.*expected_llr)]

cmin, cmax = np.min(-2*expected_llr), np.max(-2*expected_llr)
    
pcm = ax.pcolormesh(edges, edges, -2. * expected_llr.reshape((21,21)),
                    norm=matplotlib.colors.Normalize(vmin=cmin, vmax=cmax),
                    cmap='viridis_r')
cbar = fig.colorbar(pcm, ax=ax, extend='both')

plt.scatter(best_fit[0], best_fit[1], s=80., color='black', marker='*')

plt.xlabel(r'$\theta_0$')
plt.ylabel(r'$\theta_1$')
cbar.set_label(r'$\mathbb{E}_x [ -2\, \log \,\hat{r}(x | \theta, \theta_{SM}) ]$')

plt.tight_layout()
plt.show()

# %% [markdown]
# Note that in this tutorial our sample size was very small, and the network might not really have a chance to converge to the correct likelihood ratio function. So don't worry if you find a minimum that is not at the right point (the SM, i.e. the origin in this plot). Feel free to dial up the event numbers in the run card as well as the training samples and see what happens then!
